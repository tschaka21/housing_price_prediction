# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
datei_sample = 'C:\\Users\\KaiTs\Documents\\Data_Science\\Datasets\\housing price\\sample_submission.csv'
datei_test = 'C:\\Users\\KaiTs\\Documents\\Data_Science\\Datasets\\housing price\\test.csv'
datei_train ='C:\\Users\\KaiTs\\Documents\\Data_Science\\Datasets\\housing price\\train.csv'

# %%
sample = pd.read_csv(datei_sample)
test = pd.read_csv(datei_test)
train = pd.read_csv(datei_train)

# %%
sample.head()
# Out:
#      Id      SalePrice
# 0  1461  169277.052498
# 1  1462  187758.393989
# 2  1463  183583.683570
# 3  1464  179317.477511
# 4  1465  150730.079977

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
train.shape
# Out:
# (1460, 81)

# %%
train.isnull()
# Out:
#          Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     False       False     False        False    False   False   True
# 1     False       False     False        False    False   False   True
# 2     False       False     False        False    False   False   True
# 3     False       False     False        False    False   False   True
# 4     False       False     False        False    False   False   True
# ...     ...         ...       ...          ...      ...     ...    ...
# 1455  False       False     False        False    False   False   True
# 1456  False       False     False        False    False   False   True
# 1457  False       False     False        False    False   False   True
# 1458  False       False     False        False    False   False   True
# 1459  False       False     False        False    False   False   True
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
isnull = train.isnull().sum()
isnull_with_nulls = isnull[isnull > 0]
print(isnull_with_nulls)
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
import scipy.stats as stats


# Histogramm
plt.figure(figsize=(10, 6))
sns.histplot(train['SalePrice'], bins=30, kde=True, edgecolor='black', stat='density', alpha=0.7)
plt.title('Histogram of Sales Price with Density Curve')
plt.xlabel('Sales Price')
plt.ylabel('Density')
plt.show()


# QQ-Plot normal distribution
plt.figure(figsize=(10, 6))
stats.probplot(train['SalePrice'], dist="norm", plot=plt)
plt.title('QQ-Plot of Sales Price')
plt.show()

# %%
#1. Influence of dwelling type to price
dwelling_type = train['BldgType'].value_counts()
dwelling_prices = train.groupby('BldgType')['SalePrice'].mean()
dwelling_prices
# Out:
# BldgType
# 1Fam      185763.807377
# 2fmCon    128432.258065
# Duplex    133541.076923
# Twnhs     135911.627907
# TwnhsE    181959.342105
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(dwelling_prices.index, dwelling_prices, color='green', edgecolor='black')
plt.title('Influence of Dwelling Type on Sale Price', fontsize=18, weight='bold', color='black')
plt.xlabel('Dwelling Type', fontsize=14, color='black')
plt.ylabel('Average Sale Price', fontsize=14, color='black')
plt.grid(True, linestyle='--', linewidth=0.5, color='grey', axis='y')
plt.xticks(rotation=45)

for bar in bars:
    yval = bar.get_height()
    formatted_value = f'{yval:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.')
    plt.text(bar.get_x() + bar.get_width()/2, yval, formatted_value, ha='center', va='bottom', fontsize=12, color='black')

plt.show()

# %%
plt.figure(figsize=(12, 6))
bars = plt.bar(dwelling_type.index, dwelling_type, color='blue', edgecolor='black')
plt.title('Distribution of Dwelling Types', fontsize=18, weight='bold', color='black')
plt.xlabel('Dwelling Type', fontsize=14, color='black')
plt.ylabel('Frequency', fontsize=14, color='black')
plt.grid(True, linestyle='--', linewidth=0.5, color='grey', axis='y')
plt.xticks(rotation=45)


for bar in bars:
    yval = bar.get_height()
    formatted_value = f'{yval:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.')
    plt.text(bar.get_x() + bar.get_width()/2, yval, formatted_value, ha='center', va='bottom', fontsize=12, color='black')

plt.show()

# %%
zoning_prices = train.groupby('MSZoning')['SalePrice'].mean()


plt.figure(figsize=(10, 6))
bars = plt.bar(zoning_prices.index, zoning_prices, color='green', edgecolor='black')
plt.title('Influence of MSZoning on Sale Price', fontsize=18, weight='bold', color='black')
plt.xlabel('MSZoning', fontsize=14, color='black')
plt.ylabel('Average Sale Price', fontsize=14, color='black')
plt.grid(True, linestyle='--', linewidth=0.5, color='grey', axis='y')
plt.xticks(rotation=45)


for bar in bars:
    yval = bar.get_height()
    formatted_value = f'{yval:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.')
    plt.text(bar.get_x() + bar.get_width()/2, yval, formatted_value, ha='center', va='bottom', fontsize=12, color='black')

plt.show()

# %%
street_prices = train.groupby('Street')['SalePrice'].mean()

plt.figure(figsize=(10, 6))
bars = plt.bar(street_prices.index, street_prices, color='green', edgecolor='black')
plt.title('Influence of Street on Sale Price', fontsize=18, weight='bold', color='black')
plt.xlabel('Street Type', fontsize=14, color='black')
plt.ylabel('Average Sale Price', fontsize=14, color='black')
plt.grid(True, linestyle='--', linewidth=0.5, color='grey', axis='y')
plt.xticks(rotation=45)


for bar in bars:
    yval = bar.get_height()
    formatted_value = f'{yval:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.')
    plt.text(bar.get_x() + bar.get_width()/2, yval, formatted_value, ha='center', va='bottom', fontsize=12, color='black')

plt.show()

# %%
alley_prices = train.groupby('Alley')['SalePrice'].mean()
plt.figure(figsize=(10, 6))
bars = plt.bar(alley_prices.index, alley_prices, color='green', edgecolor='black')
plt.title('Influence of Alley on Sale Price', fontsize=18, weight='bold', color='black')
plt.xlabel('Alley Type', fontsize=14, color='black')
plt.ylabel('Average Sale Price', fontsize=14, color='black')
plt.grid(True, linestyle='--', linewidth=0.5, color='grey', axis='y')
plt.xticks(rotation=45)

# Werte über den Balken anzeigen
for bar in bars:
    yval = bar.get_height()
    formatted_value = f'{yval:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.')
    plt.text(bar.get_x() + bar.get_width()/2, yval, formatted_value, ha='center', va='bottom', fontsize=12, color='black')

plt.show()

# %%
lotshape_prices = train.groupby('LotShape')['SalePrice'].mean()

# Erstelle das Balkendiagramm für durchschnittliche Verkaufspreise und zeige die Werte über den Balken an
plt.figure(figsize=(10, 6))
bars = plt.bar(lotshape_prices.index, lotshape_prices, color='green', edgecolor='black')
plt.title('Influence of LotShape on Sale Price', fontsize=18, weight='bold', color='black')
plt.xlabel('LotShape', fontsize=14, color='black')
plt.ylabel('Average Sale Price', fontsize=14, color='black')
plt.grid(True, linestyle='--', linewidth=0.5, color='grey', axis='y')
plt.xticks(rotation=45)

# Werte über den Balken anzeigen
for bar in bars:
    yval = bar.get_height()
    formatted_value = f'{yval:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.')
    plt.text(bar.get_x() + bar.get_width()/2, yval, formatted_value, ha='center', va='bottom', fontsize=12, color='black')

plt.show()

# %%
landcontour_prices = train.groupby('LandContour')['SalePrice'].mean()

# Erstelle das Balkendiagramm für durchschnittliche Verkaufspreise und zeige die Werte über den Balken an
plt.figure(figsize=(10, 6))
bars = plt.bar(landcontour_prices.index, landcontour_prices, color='green', edgecolor='black')
plt.title('Influence of LandContour on Sale Price', fontsize=18, weight='bold', color='black')
plt.xlabel('LandContour', fontsize=14, color='black')
plt.ylabel('Average Sale Price', fontsize=14, color='black')
plt.grid(True, linestyle='--', linewidth=0.5, color='grey', axis='y')
plt.xticks(rotation=45)

# Werte über den Balken anzeigen
for bar in bars:
    yval = bar.get_height()
    formatted_value = f'{yval:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.')
    plt.text(bar.get_x() + bar.get_width()/2, yval, formatted_value, ha='center', va='bottom', fontsize=12, color='black')

plt.show()

# %%
train['PropertyAge'] = train['YrSold']-train['YearBuilt']

age_price_corr = train['PropertyAge'].corr(train['SalePrice'])

print(f'Correlation between Property Age and Sale Price: {age_price_corr}')

plt.figure(figsize=(10, 6))
plt.scatter(train['PropertyAge'], train['SalePrice'], alpha=0.5, color='green', edgecolors='black')
plt.title('Property Age vs Sale Price', fontsize=18, weight='bold', color='black')
plt.xlabel('Property Age', fontsize=14, color='black')
plt.ylabel('Sale Price', fontsize=14, color='black')
plt.grid(True, linestyle='--', linewidth=0.5, color='grey')
plt.text(max(train['PropertyAge']) * 0.6, max(train['SalePrice']) * 0.9, f'Corr: {age_price_corr:.2f}', fontsize=14, color='black')
plt.show()
# Out:
# Correlation between Property Age and Sale Price: -0.5233504175468161

# %%
living_area_price_corr = train['GrLivArea'].corr(train['SalePrice'])
print(f'Correlation between Living Area (above grade) and Sale Price: {living_area_price_corr}')

plt.figure(figsize=(10, 6))
plt.scatter(train['GrLivArea'], train['SalePrice'], alpha=0.5, color='green', edgecolors='black')
plt.title('Living Area vs Sale Price', fontsize=18, weight='bold', color='black')
plt.xlabel('Living Area', fontsize=14, color='black')
plt.ylabel('Sale Price', fontsize=14, color='black')
plt.grid(True, linestyle='--', linewidth=0.5, color='grey')
plt.text(max(train['GrLivArea']) * 0.6, max(train['SalePrice']) * 0.9, f'Corr: {living_area_price_corr:.2f}', fontsize=14, color='black')
plt.show()
# Out:
# Correlation between Living Area (above grade) and Sale Price: 0.7086244776126518

# %%
yearly_avg_sale_price = train.groupby('YrSold')['SalePrice'].mean()

# Erstelle das Boxplot
plt.figure(figsize=(12, 8))
boxplot = sns.boxplot(x='YrSold', y='SalePrice', data=train)
plt.title('Sale Price Distribution by Year Sold', fontsize=18, weight='bold', color='black')
plt.xlabel('Year Sold', fontsize=14, color='black')
plt.ylabel('Sale Price', fontsize=14, color='black')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', linewidth=0.5, color='grey')

# Mediane beschriften
medians = train.groupby('YrSold')['SalePrice'].median().values
for xtick in boxplot.get_xticks():
    boxplot.text(xtick, medians[xtick] + 5000, f'{medians[xtick]:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.'), 
                 horizontalalignment='center', size='medium', color='black', weight='semibold')

plt.show()

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.neural_network import MLPRegressor
import numpy as np

# Define transformers for numerical and categorical columns
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse=False))
])

# %%
# Update categorical and numerical columns
categorical_columns = train.select_dtypes(include=['object', 'category']).columns
numerical_columns = train.select_dtypes(include=['int64', 'float64']).columns

# Remove target variable from numerical columns
numerical_columns = numerical_columns.drop('SalePrice')

# Combine transformers using ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_columns),
        ('cat', categorical_transformer, categorical_columns)
    ], remainder='passthrough'
)

# Train-Test-Split
X = train.drop('SalePrice', axis=1)
y = np.log(train['SalePrice'])

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error


# Train-Test-Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Modelle und Parametergitter
models = {
    'Linear Regression': LinearRegression(),
    'Random Forest': RandomForestRegressor(random_state=0),
    'XGBoost': XGBRegressor(random_state=0),
    'Gradient Boosting': GradientBoostingRegressor(random_state=0)
}

param_grids = {
    'Linear Regression': {},
    'Random Forest': {
        'n_estimators': [50, 100, 200],
        'max_depth': [None, 10, 20],
        'min_samples_split': [2, 5, 10]
    },
    'XGBoost': {
        'n_estimators': [50, 100, 200],
        'max_depth': [3, 6, 9],
        'learning_rate': [0.01, 0.1, 0.2]
    },
    'Gradient Boosting': {
        'n_estimators': [50, 100, 200],
        'max_depth': [3, 6, 9],
        'learning_rate': [0.01, 0.1, 0.2]
    }
}

# KFold und GridSearchCV
kfold = KFold(n_splits=5, shuffle=True, random_state=0)
best_models = {}

for model_name in models:
    print(f"Training {model_name}...")
    model = models[model_name]
    param_grid = param_grids[model_name]
    
    pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('model', model)])
    
    grid_search = GridSearchCV(pipeline, param_grid={'model__' + key: value for key, value in param_grid.items()}, cv=kfold, scoring='neg_mean_squared_error', n_jobs=-1, verbose=1)
    grid_search.fit(X_train, y_train)
    
    best_models[model_name] = grid_search.best_estimator_
    print(f"Best parameters for {model_name}: {grid_search.best_params_}")
    print(f"Best score for {model_name}: {np.sqrt(-grid_search.best_score_)}")

# Modellbewertung
for model_name in best_models:
    model = best_models[model_name]
    y_pred = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    print(f"Test RMSE for {model_name}: {rmse}")
# Out:
# Training Linear Regression...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\KaiTs\anaconda3neu\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Best parameters for Linear Regression: {}
# Best score for Linear Regression: 5184385206.023274
# Training Random Forest...
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# c:\Users\KaiTs\anaconda3neu\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Best parameters for Random Forest: {'model__max_depth': 20, 'model__min_samples_split': 2, 'model__n_estimators': 200}
# ...

# %%
# MLP Regressor und Parametergitter
mlp_model = MLPRegressor(random_state=0, max_iter=1000)
param_grid_mlp = {
    'hidden_layer_sizes': [(50,), (100,), (100, 50)],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate_init': [0.001, 0.01, 0.1]
}

# Pipeline für den MLPRegressor
pipeline_mlp = Pipeline(steps=[('preprocessor', preprocessor), ('model', mlp_model)])

grid_search_mlp = GridSearchCV(pipeline_mlp, param_grid={'model__' + key: value for key, value in param_grid_mlp.items()}, cv=kfold, scoring='neg_mean_squared_error', n_jobs=-1, verbose=1)
grid_search_mlp.fit(X_train, y_train)

best_model_mlp = grid_search_mlp.best_estimator_
print(f"Best parameters for MLP Regressor: {grid_search_mlp.best_params_}")
print(f"Best score for MLP Regressor: {np.sqrt(-grid_search_mlp.best_score_)}")

# Modellbewertung für den MLP Regressor
y_pred_mlp = best_model_mlp.predict(X_test)
rmse_mlp = np.sqrt(mean_squared_error(y_test, y_pred_mlp))
print(f"Test RMSE for MLP Regressor: {rmse_mlp}")
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# c:\Users\KaiTs\anaconda3neu\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Best parameters for MLP Regressor: {'model__alpha': 0.01, 'model__hidden_layer_sizes': (50,), 'model__learning_rate_init': 0.01}
# Best score for MLP Regressor: 0.2040218887205253
# Test RMSE for MLP Regressor: 0.28515531019873364
